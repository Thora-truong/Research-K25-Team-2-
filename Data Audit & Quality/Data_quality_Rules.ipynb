# %%
## Missing Values
- Check all missing values.
- Treat blank cells separately.

## Duplicates
- Check duplicate rows.
- Check duplicate DestinationRef, ShipToID, and GroupID.

## Coordinate Validation
- Latitude must be between -90 and 90.
- Longitude must be between -180 and 180.

## Volume Validation
- KG cannot be negative.
- CBM cannot be negative.

## Data Types
- Latitude, Longitude, KG, and CBM should be numeric.
